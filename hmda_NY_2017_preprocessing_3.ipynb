# %% [markdown]
# Original dataset: https://www.consumerfinance.gov/data-research/hmda/historic-data/?geo=ny&records=all-records&field_descriptions=labels
#
# # So far from original dataset:
# 1) Selected "no co-applicant" records from the column "co_applicant_ethnicity_name"
# 2) Filter columns:
#     - action_taken_name
#     - denial_reason_name_1
# 3) Created the column "action_taken":
#     - df['action_taken'] = df['action_taken_name'].replace({
#     'Loan originated': 'approved',
#     'Application approved but not accepted': 'approved',
#     'Application denied by financial institution': 'denied'
# })
# 4) First feature selection:
#     - df = df[
#
#         ['loan_type_name',
#         'property_type_name',
#         'loan_purpose_name',
#         'loan_amount_000s',
#         'action_taken',
#         'msamd_name',
#         'applicant_ethnicity_name',
#         'applicant_race_name_1',
#         'applicant_sex_name',
#         'applicant_income_000s',
#         'denial_reason_name_1',
#         'denial_reason_name_2',
#         'denial_reason_name_3',
#         'rate_spread',
#         'lien_status_name',
#         'minority_population',
#         'hud_median_family_income',
#         'tract_to_msamd_income']
#
#         ]
# 5) Excluded "Credit application incomplete" records from the column "denial_reason_name_1"

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/nonox/hmdaNY27082024_2.csv')


print("Shape:",df.shape, "\n")

print(df.head())
# Out:
# Shape: (183483, 18)
#
#   loan_type_name                                 property_type_name  \
# 0   Conventional  One-to-four family dwelling (other than manufa...
# 1   Conventional  One-to-four family dwelling (other than manufa...
# 2   Conventional  One-to-four family dwelling (other than manufa...
# 3   Conventional                               Manufactured housing
# 4   Conventional  One-to-four family dwelling (other than manufa...
#
#   loan_purpose_name  loan_amount_000s action_taken  \
# 0     Home purchase               705     approved
# 1       Refinancing               112     approved
# 2     Home purchase               356       denied
# 3     Home purchase                58       denied
# 4       Refinancing               100     approved
#
#                                      msamd_name  \
# 0  New York, Jersey City, White Plains - NY, NJ
# 1                                           NaN
# 2  New York, Jersey City, White Plains - NY, NJ
# 3                              Utica, Rome - NY
# 4  New York, Jersey City, White Plains - NY, NJ
#
#                             applicant_ethnicity_name  \
# 0  Information not provided by applicant in mail,...
# 1                             Not Hispanic or Latino
# 2                             Not Hispanic or Latino
# 3  Information not provided by applicant in mail,...
# 4                             Not Hispanic or Latino
#
#                                applicant_race_name_1  \
# 0  Information not provided by applicant in mail,...
# 1  Information not provided by applicant in mail,...
# 2                                              White
# 3                                              White
# 4                          Black or African American
#
#                                   applicant_sex_name  applicant_income_000s  \
# 0  Information not provided by applicant in mail,...                  462.0
# 1                                             Female                   96.0
# 2                                               Male                  115.0
# 3                                             Female                   25.0
# 4                                               Male                   84.0
#
#    denial_reason_name_1 denial_reason_name_2 denial_reason_name_3  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                 Other                  NaN                  NaN
# 3  Debt-to-income ratio                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
#
#    rate_spread         lien_status_name  minority_population  \
# 0          NaN  Secured by a first lien            16.330000
# 1          NaN  Secured by a first lien             9.520000
# 2          NaN  Secured by a first lien            45.540001
# 3          NaN  Secured by a first lien             9.050000
# 4          NaN  Secured by a first lien            99.540001
#
#    hud_median_family_income  tract_to_msamd_income
# 0                   73700.0             291.769989
# 1                   62500.0             164.960007
# 2                   73700.0              81.410004
# 3                   62100.0             134.279999
# 4                   73700.0             150.360001

# %%
print("Column names:", '\n')
print(df.columns)
# Out:
# Column names:
#
# Index(['loan_type_name', 'property_type_name', 'loan_purpose_name',
#        'loan_amount_000s', 'action_taken', 'msamd_name',
#        'applicant_ethnicity_name', 'applicant_race_name_1',
#        'applicant_sex_name', 'applicant_income_000s', 'denial_reason_name_1',
#        'denial_reason_name_2', 'denial_reason_name_3', 'rate_spread',
#        'lien_status_name', 'minority_population', 'hud_median_family_income',
#        'tract_to_msamd_income'],
#       dtype='object')

# %% [markdown]
# # A) Creation of New column "race_sex"

# %%
# Creating the ethnicity_race_sex
df['race_sex'] = df['applicant_race_name_1'].str.lower() + "_" + df['applicant_sex_name'].str.lower()

# Checking column created
print(df[['race_sex']].value_counts())
# Out:
# race_sex
# white_male                                                                                                                                                             73939
# white_female                                                                                                                                                           46676
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13389
# asian_male                                                                                                                                                              9484
# black or african american_female                                                                                                                                        8401
# black or african american_male                                                                                                                                          7093
# asian_female                                                                                                                                                            6484
# information not provided by applicant in mail, internet, or telephone application_male                                                                                  6029
# not applicable_not applicable                                                                                                                                           5958
# information not provided by applicant in mail, internet, or telephone application_female                                                                                3999
# american indian or alaska native_male                                                                                                                                    633
# american indian or alaska native_female                                                                                                                                  440
# native hawaiian or other pacific islander_male                                                                                                                           355
# white_information not provided by applicant in mail, internet, or telephone application                                                                                  240
# native hawaiian or other pacific islander_female                                                                                                                         223
# black or african american_information not provided by applicant in mail, internet, or telephone application                                                               41
# asian_information not provided by applicant in mail, internet, or telephone application                                                                                   30
# american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                        16
# not applicable_male                                                                                                                                                       16
# information not provided by applicant in mail, internet, or telephone application_not applicable                                                                          14
# not applicable_female                                                                                                                                                      9
# white_not applicable                                                                                                                                                       6
# not applicable_information not provided by applicant in mail, internet, or telephone application                                                                           4
# asian_not applicable                                                                                                                                                       2
# black or african american_not applicable                                                                                                                                   1
# native hawaiian or other pacific islander_information not provided by applicant in mail, internet, or telephone application                                                1
# Name: count, dtype: int64

# %%
# New CSV file
df.to_csv('C:/Users/nonox/hmdaNYrace_sex.csv', index=False)

print(f"Dataset saved to '{'C:/Users/nonox/hmdaNYrace_sex.csv'}'")
# Out:
# Dataset saved to 'C:/Users/nonox/hmdaNYrace_sex.csv'

# %% [markdown]
# # B) No Inof
#      We filter cases with missing information for the column "race_sex"
#      the purpose is to investigate visually this dataset.

# %%
# Filter cases with no inf. for either sex or race

OnlyNoInf = df[df['race_sex'] == "information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application"]
print(OnlyNoInf)
# Out:
#        loan_type_name                                 property_type_name  \
# 0        Conventional  One-to-four family dwelling (other than manufa...
# 12       Conventional  One-to-four family dwelling (other than manufa...
# 20       Conventional  One-to-four family dwelling (other than manufa...
# 22       Conventional  One-to-four family dwelling (other than manufa...
# 33        FHA-insured  One-to-four family dwelling (other than manufa...
# ...               ...                                                ...
# 183453   Conventional  One-to-four family dwelling (other than manufa...
# 183454   Conventional  One-to-four family dwelling (other than manufa...
# 183470   Conventional  One-to-four family dwelling (other than manufa...
# 183477   Conventional  One-to-four family dwelling (other than manufa...
# 183481   Conventional  One-to-four family dwelling (other than manufa...
#
#        loan_purpose_name  loan_amount_000s action_taken  \
# 0          Home purchase               705     approved
# 12         Home purchase               147     approved
# 20         Home purchase               160     approved
# 22      Home improvement                10     approved
# 33           Refinancing                86     approved
# ...                  ...               ...          ...
# 183453       Refinancing               394       denied
# 183454       Refinancing               100     approved
# 183470  Home improvement                55       denied
# 183477       Refinancing               340       denied
# 183481  Home improvement                80       denied
#
#                                           msamd_name  \
# 0       New York, Jersey City, White Plains - NY, NJ
# 12                                       Elmira - NY
# 20          Buffalo, Cheektowaga, Niagara Falls - NY
# 22                                    Rochester - NY
# 33                                    Rochester - NY
# ...                                              ...
# 183453  New York, Jersey City, White Plains - NY, NJ
# 183454  New York, Jersey City, White Plains - NY, NJ
# 183470  New York, Jersey City, White Plains - NY, NJ
# 183477  New York, Jersey City, White Plains - NY, NJ
# 183481  New York, Jersey City, White Plains - NY, NJ
#
#                                  applicant_ethnicity_name  \
# 0       Information not provided by applicant in mail,...
# 12      Information not provided by applicant in mail,...
# 20      Information not provided by applicant in mail,...
# 22      Information not provided by applicant in mail,...
# 33      Information not provided by applicant in mail,...
# ...                                                   ...
# 183453  Information not provided by applicant in mail,...
# 183454  Information not provided by applicant in mail,...
# 183470  Information not provided by applicant in mail,...
# 183477  Information not provided by applicant in mail,...
# 183481  Information not provided by applicant in mail,...
#
#                                     applicant_race_name_1  \
# 0       Information not provided by applicant in mail,...
# 12      Information not provided by applicant in mail,...
# 20      Information not provided by applicant in mail,...
# 22      Information not provided by applicant in mail,...
# 33      Information not provided by applicant in mail,...
# ...                                                   ...
# 183453  Information not provided by applicant in mail,...
# 183454  Information not provided by applicant in mail,...
# 183470  Information not provided by applicant in mail,...
# 183477  Information not provided by applicant in mail,...
# 183481  Information not provided by applicant in mail,...
#
#                                        applicant_sex_name  \
# 0       Information not provided by applicant in mail,...
# 12      Information not provided by applicant in mail,...
# 20      Information not provided by applicant in mail,...
# 22      Information not provided by applicant in mail,...
# 33      Information not provided by applicant in mail,...
# ...                                                   ...
# 183453  Information not provided by applicant in mail,...
# 183454  Information not provided by applicant in mail,...
# 183470  Information not provided by applicant in mail,...
# 183477  Information not provided by applicant in mail,...
# 183481  Information not provided by applicant in mail,...
#
#         applicant_income_000s  denial_reason_name_1 denial_reason_name_2  \
# 0                       462.0                   NaN                  NaN
# 12                      223.0                   NaN                  NaN
# 20                       48.0                   NaN                  NaN
# 22                       57.0                   NaN                  NaN
# 33                       56.0                   NaN                  NaN
# ...                       ...                   ...                  ...
# 183453                  105.0  Debt-to-income ratio                  NaN
# 183454                  104.0                   NaN                  NaN
# 183470                  116.0  Debt-to-income ratio       Credit history
# 183477                   30.0  Debt-to-income ratio                  NaN
# 183481                  105.0  Debt-to-income ratio                  NaN
#
#        denial_reason_name_3  rate_spread               lien_status_name  \
# 0                       NaN          NaN        Secured by a first lien
# 12                      NaN          NaN        Secured by a first lien
# 20                      NaN          NaN        Secured by a first lien
# 22                      NaN          NaN  Secured by a subordinate lien
# 33                      NaN          NaN        Secured by a first lien
# ...                     ...          ...                            ...
# 183453                  NaN          NaN        Secured by a first lien
# 183454                  NaN          NaN        Secured by a first lien
# 183470                  NaN          NaN          Not secured by a lien
# 183477                  NaN          NaN        Secured by a first lien
# 183481                  NaN          NaN          Not secured by a lien
#
#         minority_population  hud_median_family_income  tract_to_msamd_income  \
# 0                 16.330000                   73700.0             291.769989
# 12                 7.730000                   64600.0             146.889999
# 20                 7.590000                   68200.0              93.279999
# 22                 5.850000                   68500.0              93.489998
# 33                 7.580000                   68500.0             124.059998
# ...                     ...                       ...                    ...
# 183453            35.509998                   73700.0             177.520004
# 183454            35.509998                   73700.0             177.520004
# 183470            27.790001                   73700.0             190.190002
# 183477            24.350000                   73700.0             205.369995
# 183481            18.110001                   73700.0             225.089996
#
#                                                  race_sex
# 0       information not provided by applicant in mail,...
# 12      information not provided by applicant in mail,...
# 20      information not provided by applicant in mail,...
# 22      information not provided by applicant in mail,...
# 33      information not provided by applicant in mail,...
# ...                                                   ...
# 183453  information not provided by applicant in mail,...
# 183454  information not provided by applicant in mail,...
# 183470  information not provided by applicant in mail,...
# 183477  information not provided by applicant in mail,...
# 183481  information not provided by applicant in mail,...
#
# [13389 rows x 19 columns]

# %%
# New CSV file with 
OnlyNoInf.to_csv('C:/Users/nonox/OnlyNoInf.csv', index=False)

print(f"Filtered dataset saved to '{'C:/Users/nonox/OnlyNoInf.csv'}'")
# Out:
# Filtered dataset saved to 'C:/Users/nonox/OnlyNoInf.csv'

# %% [markdown]
# # C) New column "ethnicity_race_sex"

# %%
# Creating the ethnicity_race_sex
df['ethnicity_race_sex'] = df['applicant_ethnicity_name'].str.lower() + "_" + df['applicant_race_name_1'].str.lower() + "_" + df['applicant_sex_name'].str.lower()

# Checking column created
print(df[['ethnicity_race_sex']].value_counts())
# Out:
# ethnicity_race_sex
# not hispanic or latino_white_male                                                                                                                                                                                                                        66819
# not hispanic or latino_white_female                                                                                                                                                                                                                      42594
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13223
# not hispanic or latino_asian_male                                                                                                                                                                                                                         9289
# not hispanic or latino_black or african american_female                                                                                                                                                                                                   7852
#                                                                                                                                                                                                                                                          ...
# not applicable_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                       1
# information not provided by applicant in mail, internet, or telephone application_black or african american_not applicable                                                                                                                                   1
# not applicable_asian_female                                                                                                                                                                                                                                  1
# hispanic or latino_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                                                                                        1
# not applicable_white_not applicable                                                                                                                                                                                                                          1
# Name: count, Length: 73, dtype: int64

# %%
# Check records for each column
for column in df:
    print(f"Distinct records and their counts for '{column}':")
    print(df[column].value_counts())
    print("\n" + "=+"*50 + "\n")
# Out:
# Distinct records and their counts for 'loan_type_name':
# loan_type_name
# Conventional          148599
# FHA-insured            27042
# VA-guaranteed           6474
# FSA/RHS-guaranteed      1368
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'property_type_name':
# property_type_name
# One-to-four family dwelling (other than manufactured housing)    175723
# Manufactured housing                                               4648
# Multifamily dwelling                                               3112
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_purpose_name':
# loan_purpose_name
# Home purchase       96867
# Refinancing         58950
# Home improvement    27666
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_amount_000s':
# loan_amount_000s
# 10      2859
# 5       2255
# 100     2089
# 50      1713
# 15      1680
#         ...
# 1994       1
# 1291       1
# 5146       1
# 6068       1
# 7083       1
# Name: count, Length: 2666, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'action_taken':
# action_taken
# approved    142370
# denied       41113
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'msamd_name':
# msamd_name
# New York, Jersey City, White Plains - NY, NJ    65430
# Nassau County, Suffolk County - NY              30470
# Rochester - NY                                  15262
# Buffalo, Cheektowaga, Niagara Falls - NY        14687
# Albany, Schenectady, Troy - NY                  11682
# Syracuse - NY                                    9141
# Dutchess County, Putnam County - NY              4811
# Utica, Rome - NY                                 4544
# Binghamton - NY                                  2693
# Kingston - NY                                    2192
# Glens Falls - NY                                 1775
# Watertown, Fort Drum - NY                        1594
# Elmira - NY                                      1363
# Ithaca - NY                                       865
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_ethnicity_name':
# applicant_ethnicity_name
# Not Hispanic or Latino                                                               143363
# Information not provided by applicant in mail, Internet, or telephone application     21418
# Hispanic or Latino                                                                    12613
# Not applicable                                                                         6089
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_race_name_1':
# applicant_race_name_1
# White                                                                                120861
# Information not provided by applicant in mail, Internet, or telephone application     23431
# Asian                                                                                 16000
# Black or African American                                                             15536
# Not applicable                                                                         5987
# American Indian or Alaska Native                                                       1089
# Native Hawaiian or Other Pacific Islander                                               579
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_sex_name':
# applicant_sex_name
# Male                                                                                 97549
# Female                                                                               66232
# Information not provided by applicant in mail, Internet, or telephone application    13721
# Not applicable                                                                        5981
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_income_000s':
# applicant_income_000s
# 60.0      2554
# 50.0      2251
# 52.0      1998
# 42.0      1990
# 65.0      1931
#           ...
# 5908.0       1
# 1067.0       1
# 1161.0       1
# 1874.0       1
# 3485.0       1
# Name: count, Length: 1896, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_1':
# denial_reason_name_1
# Debt-to-income ratio                              10392
# Credit history                                     8636
# Collateral                                         5948
# Other                                              2813
# Insufficient cash (downpayment, closing costs)      924
# Unverifiable information                            905
# Employment history                                  403
# Mortgage insurance denied                            67
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_2':
# denial_reason_name_2
# Credit history                                    2018
# Debt-to-income ratio                              1451
# Other                                             1085
# Insufficient cash (downpayment, closing costs)     773
# Collateral                                         727
# Unverifiable information                           449
# Credit application incomplete                      339
# Employment history                                 236
# Mortgage insurance denied                           42
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_3':
# denial_reason_name_3
# Other                                             318
# Insufficient cash (downpayment, closing costs)    182
# Credit history                                    167
# Debt-to-income ratio                              123
# Collateral                                        114
# Unverifiable information                          103
# Credit application incomplete                      60
# Employment history                                 21
# Mortgage insurance denied                          13
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'rate_spread':
# rate_spread
# 1.50    170
# 1.51    137
# 1.55    133
# 1.54    125
# 1.57    116
#        ...
# 7.44      1
# 5.77      1
# 3.65      1
# 4.47      1
# 6.39      1
# Name: count, Length: 532, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'lien_status_name':
# lien_status_name
# Secured by a first lien          159535
# Not secured by a lien             16640
# Secured by a subordinate lien      7308
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'minority_population':
# minority_population
# 100.000000    680
# 4.680000      338
# 2.960000      333
# 21.540001     308
# 6.640000      279
#              ...
# 58.970001       1
# 87.339996       1
# 39.639999       1
# 38.070000       1
# 72.230003       1
# Name: count, Length: 3498, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'hud_median_family_income':
# hud_median_family_income
# 73700.0     65441
# 110800.0    30471
# 62500.0     16584
# 68500.0     15268
# 68200.0     14688
# 83100.0     11684
# 68000.0      9142
# 97100.0      4811
# 62100.0      4550
# 65700.0      2697
# 78500.0      2193
# 64100.0      1776
# 62400.0      1594
# 64600.0      1363
# 75600.0       865
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'tract_to_msamd_income':
# tract_to_msamd_income
# 346.989990    1696
# 124.949997     300
# 0.000000       243
# 143.570007     235
# 117.559998     231
#               ...
# 31.799999        1
# 55.369999        1
# 19.790001        1
# 37.919998        1
# 26.250000        1
# Name: count, Length: 3920, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'race_sex':
# race_sex
# white_male                                                                                                                                                             73939
# white_female                                                                                                                                                           46676
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13389
# asian_male                                                                                                                                                              9484
# black or african american_female                                                                                                                                        8401
# black or african american_male                                                                                                                                          7093
# asian_female                                                                                                                                                            6484
# information not provided by applicant in mail, internet, or telephone application_male                                                                                  6029
# not applicable_not applicable                                                                                                                                           5958
# information not provided by applicant in mail, internet, or telephone application_female                                                                                3999
# american indian or alaska native_male                                                                                                                                    633
# american indian or alaska native_female                                                                                                                                  440
# native hawaiian or other pacific islander_male                                                                                                                           355
# white_information not provided by applicant in mail, internet, or telephone application                                                                                  240
# native hawaiian or other pacific islander_female                                                                                                                         223
# black or african american_information not provided by applicant in mail, internet, or telephone application                                                               41
# asian_information not provided by applicant in mail, internet, or telephone application                                                                                   30
# american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                        16
# not applicable_male                                                                                                                                                       16
# information not provided by applicant in mail, internet, or telephone application_not applicable                                                                          14
# not applicable_female                                                                                                                                                      9
# white_not applicable                                                                                                                                                       6
# not applicable_information not provided by applicant in mail, internet, or telephone application                                                                           4
# asian_not applicable                                                                                                                                                       2
# native hawaiian or other pacific islander_information not provided by applicant in mail, internet, or telephone application                                                1
# black or african american_not applicable                                                                                                                                   1
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'ethnicity_race_sex':
# ethnicity_race_sex
# not hispanic or latino_white_male                                                                                                                                                                                                                        66819
# not hispanic or latino_white_female                                                                                                                                                                                                                      42594
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13223
# not hispanic or latino_asian_male                                                                                                                                                                                                                         9289
# not hispanic or latino_black or african american_female                                                                                                                                                                                                   7852
#                                                                                                                                                                                                                                                          ...
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_not applicable                                                                                                                                          1
# information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_information not provided by applicant in mail, internet, or telephone application                                                1
# not applicable_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                       1
# not applicable_white_not applicable                                                                                                                                                                                                                          1
# not applicable_asian_female                                                                                                                                                                                                                                  1
# Name: count, Length: 73, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+

# %%
### 1) Drop "race_sex" column

df = df.drop(columns=['race_sex'])

# %%
# Save the new dataset with only the new column "ethnicity_race_sex"

df.to_csv('C:/Users/nonox/hmdaNY_eRs_29082024_1251.csv', index=False)

print(f"Filtered dataset saved to '{'C:/Users/nonox/hmdaNY_eRs_29082024_1251.csv'}'")
# Out:
# Filtered dataset saved to 'C:/Users/nonox/hmdaNY_eRs_29082024_1251.csv'

# %%
df = pd.read_csv('C:/Users/nonox/hmdaNY_eRs_29082024_1251.csv')

# Print the values for each record of each column
for column in df:
    print(f"Distinct records and their counts for '{column}':")
    print(df[column].value_counts())
    print("\n" + "=+"*50 + "\n")
# Out:
# Distinct records and their counts for 'loan_type_name':
# loan_type_name
# Conventional          148599
# FHA-insured            27042
# VA-guaranteed           6474
# FSA/RHS-guaranteed      1368
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'property_type_name':
# property_type_name
# One-to-four family dwelling (other than manufactured housing)    175723
# Manufactured housing                                               4648
# Multifamily dwelling                                               3112
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_purpose_name':
# loan_purpose_name
# Home purchase       96867
# Refinancing         58950
# Home improvement    27666
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_amount_000s':
# loan_amount_000s
# 10      2859
# 5       2255
# 100     2089
# 50      1713
# 15      1680
#         ...
# 1994       1
# 1291       1
# 5146       1
# 6068       1
# 7083       1
# Name: count, Length: 2666, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'action_taken':
# action_taken
# approved    142370
# denied       41113
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'msamd_name':
# msamd_name
# New York, Jersey City, White Plains - NY, NJ    65430
# Nassau County, Suffolk County - NY              30470
# Rochester - NY                                  15262
# Buffalo, Cheektowaga, Niagara Falls - NY        14687
# Albany, Schenectady, Troy - NY                  11682
# Syracuse - NY                                    9141
# Dutchess County, Putnam County - NY              4811
# Utica, Rome - NY                                 4544
# Binghamton - NY                                  2693
# Kingston - NY                                    2192
# Glens Falls - NY                                 1775
# Watertown, Fort Drum - NY                        1594
# Elmira - NY                                      1363
# Ithaca - NY                                       865
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_ethnicity_name':
# applicant_ethnicity_name
# Not Hispanic or Latino                                                               143363
# Information not provided by applicant in mail, Internet, or telephone application     21418
# Hispanic or Latino                                                                    12613
# Not applicable                                                                         6089
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_race_name_1':
# applicant_race_name_1
# White                                                                                120861
# Information not provided by applicant in mail, Internet, or telephone application     23431
# Asian                                                                                 16000
# Black or African American                                                             15536
# Not applicable                                                                         5987
# American Indian or Alaska Native                                                       1089
# Native Hawaiian or Other Pacific Islander                                               579
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_sex_name':
# applicant_sex_name
# Male                                                                                 97549
# Female                                                                               66232
# Information not provided by applicant in mail, Internet, or telephone application    13721
# Not applicable                                                                        5981
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'applicant_income_000s':
# applicant_income_000s
# 60.0      2554
# 50.0      2251
# 52.0      1998
# 42.0      1990
# 65.0      1931
#           ...
# 5908.0       1
# 1067.0       1
# 1161.0       1
# 1874.0       1
# 3485.0       1
# Name: count, Length: 1896, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_1':
# denial_reason_name_1
# Debt-to-income ratio                              10392
# Credit history                                     8636
# Collateral                                         5948
# Other                                              2813
# Insufficient cash (downpayment, closing costs)      924
# Unverifiable information                            905
# Employment history                                  403
# Mortgage insurance denied                            67
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_2':
# denial_reason_name_2
# Credit history                                    2018
# Debt-to-income ratio                              1451
# Other                                             1085
# Insufficient cash (downpayment, closing costs)     773
# Collateral                                         727
# Unverifiable information                           449
# Credit application incomplete                      339
# Employment history                                 236
# Mortgage insurance denied                           42
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'denial_reason_name_3':
# denial_reason_name_3
# Other                                             318
# Insufficient cash (downpayment, closing costs)    182
# Credit history                                    167
# Debt-to-income ratio                              123
# Collateral                                        114
# Unverifiable information                          103
# Credit application incomplete                      60
# Employment history                                 21
# Mortgage insurance denied                          13
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'rate_spread':
# rate_spread
# 1.50    170
# 1.51    137
# 1.55    133
# 1.54    125
# 1.57    116
#        ...
# 7.44      1
# 5.77      1
# 3.65      1
# 4.47      1
# 6.39      1
# Name: count, Length: 532, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'lien_status_name':
# lien_status_name
# Secured by a first lien          159535
# Not secured by a lien             16640
# Secured by a subordinate lien      7308
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'minority_population':
# minority_population
# 100.000000    680
# 4.680000      338
# 2.960000      333
# 21.540001     308
# 6.640000      279
#              ...
# 58.970001       1
# 87.339996       1
# 39.639999       1
# 38.070000       1
# 72.230003       1
# Name: count, Length: 3498, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'hud_median_family_income':
# hud_median_family_income
# 73700.0     65441
# 110800.0    30471
# 62500.0     16584
# 68500.0     15268
# 68200.0     14688
# 83100.0     11684
# 68000.0      9142
# 97100.0      4811
# 62100.0      4550
# 65700.0      2697
# 78500.0      2193
# 64100.0      1776
# 62400.0      1594
# 64600.0      1363
# 75600.0       865
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'tract_to_msamd_income':
# tract_to_msamd_income
# 346.989990    1696
# 124.949997     300
# 0.000000       243
# 143.570007     235
# 117.559998     231
#               ...
# 31.799999        1
# 55.369999        1
# 19.790001        1
# 37.919998        1
# 26.250000        1
# Name: count, Length: 3920, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'ethnicity_race_sex':
# ethnicity_race_sex
# not hispanic or latino_white_male                                                                                                                                                                                                                        66819
# not hispanic or latino_white_female                                                                                                                                                                                                                      42594
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13223
# not hispanic or latino_asian_male                                                                                                                                                                                                                         9289
# not hispanic or latino_black or african american_female                                                                                                                                                                                                   7852
#                                                                                                                                                                                                                                                          ...
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_not applicable                                                                                                                                          1
# information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_information not provided by applicant in mail, internet, or telephone application                                                1
# not applicable_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                       1
# not applicable_white_not applicable                                                                                                                                                                                                                          1
# not applicable_asian_female                                                                                                                                                                                                                                  1
# Name: count, Length: 73, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+

# %%
pd.set_option('display.max_rows', None)
print(df['ethnicity_race_sex'].value_counts())
# Out:
# ethnicity_race_sex
# not hispanic or latino_white_male                                                                                                                                                                                                                        66819
# not hispanic or latino_white_female                                                                                                                                                                                                                      42594
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application    13223
# not hispanic or latino_asian_male                                                                                                                                                                                                                         9289
# not hispanic or latino_black or african american_female                                                                                                                                                                                                   7852
# not hispanic or latino_black or african american_male                                                                                                                                                                                                     6588
# not hispanic or latino_asian_female                                                                                                                                                                                                                       6354
# hispanic or latino_white_male                                                                                                                                                                                                                             6199
# not applicable_not applicable_not applicable                                                                                                                                                                                                              5958
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_male                                                                                  3580
# hispanic or latino_white_female                                                                                                                                                                                                                           3476
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_female                                                                                2446
# not hispanic or latino_information not provided by applicant in mail, internet, or telephone application_male                                                                                                                                             1418
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_male                                                                                                                                                 1015
# not hispanic or latino_information not provided by applicant in mail, internet, or telephone application_female                                                                                                                                            904
# information not provided by applicant in mail, internet, or telephone application_white_male                                                                                                                                                               892
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_female                                                                                                                                                642
# information not provided by applicant in mail, internet, or telephone application_white_female                                                                                                                                                             583
# not hispanic or latino_american indian or alaska native_male                                                                                                                                                                                               441
# hispanic or latino_black or african american_female                                                                                                                                                                                                        383
# not hispanic or latino_american indian or alaska native_female                                                                                                                                                                                             351
# hispanic or latino_black or african american_male                                                                                                                                                                                                          339
# not hispanic or latino_native hawaiian or other pacific islander_male                                                                                                                                                                                      244
# information not provided by applicant in mail, internet, or telephone application_black or african american_female                                                                                                                                         162
# not hispanic or latino_native hawaiian or other pacific islander_female                                                                                                                                                                                    161
# information not provided by applicant in mail, internet, or telephone application_black or african american_male                                                                                                                                           160
# hispanic or latino_american indian or alaska native_male                                                                                                                                                                                                   159
# not hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                             150
# not hispanic or latino_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application                                                                 139
# information not provided by applicant in mail, internet, or telephone application_asian_male                                                                                                                                                               121
# hispanic or latino_native hawaiian or other pacific islander_male                                                                                                                                                                                          101
# information not provided by applicant in mail, internet, or telephone application_white_information not provided by applicant in mail, internet, or telephone application                                                                                   80
# hispanic or latino_american indian or alaska native_female                                                                                                                                                                                                  80
# information not provided by applicant in mail, internet, or telephone application_asian_female                                                                                                                                                              74
# hispanic or latino_asian_male                                                                                                                                                                                                                               71
# hispanic or latino_native hawaiian or other pacific islander_female                                                                                                                                                                                         59
# hispanic or latino_asian_female                                                                                                                                                                                                                             55
# information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_male                                                                                                                                     33
# not applicable_white_male                                                                                                                                                                                                                                   29
# not hispanic or latino_asian_information not provided by applicant in mail, internet, or telephone application                                                                                                                                              24
# not applicable_white_female                                                                                                                                                                                                                                 23
# not hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application                                                                                                                          22
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application                                                                      20
# information not provided by applicant in mail, internet, or telephone application_black or african american_information not provided by applicant in mail, internet, or telephone application                                                               17
# not applicable_information not provided by applicant in mail, internet, or telephone application_male                                                                                                                                                       16
# not applicable_not applicable_male                                                                                                                                                                                                                          16
# information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_male                                                                                                                            10
# information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                         9
# information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_female                                                                                                                                    9
# not applicable_not applicable_female                                                                                                                                                                                                                         9
# information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_not applicable                                                                           9
# hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                   9
# not applicable_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application                                                                           7
# not applicable_information not provided by applicant in mail, internet, or telephone application_female                                                                                                                                                      7
# not hispanic or latino_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                                                                                    6
# not applicable_black or african american_male                                                                                                                                                                                                                6
# information not provided by applicant in mail, internet, or telephone application_asian_information not provided by applicant in mail, internet, or telephone application                                                                                    5
# not hispanic or latino_white_not applicable                                                                                                                                                                                                                  5
# not applicable_information not provided by applicant in mail, internet, or telephone application_not applicable                                                                                                                                              4
# not applicable_not applicable_information not provided by applicant in mail, internet, or telephone application                                                                                                                                              4
# not applicable_black or african american_female                                                                                                                                                                                                              4
# information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_female                                                                                                                           3
# not applicable_asian_male                                                                                                                                                                                                                                    3
# hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application                                                                                                                               2
# not hispanic or latino_asian_not applicable                                                                                                                                                                                                                  2
# hispanic or latino_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application                                                                                                                        1
# hispanic or latino_asian_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                   1
# information not provided by applicant in mail, internet, or telephone application_black or african american_not applicable                                                                                                                                   1
# hispanic or latino_information not provided by applicant in mail, internet, or telephone application_not applicable                                                                                                                                          1
# information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_information not provided by applicant in mail, internet, or telephone application                                                1
# not applicable_white_information not provided by applicant in mail, internet, or telephone application                                                                                                                                                       1
# not applicable_white_not applicable                                                                                                                                                                                                                          1
# not applicable_asian_female                                                                                                                                                                                                                                  1
# Name: count, dtype: int64

# %% [markdown]
# # D) QUESTIONS

# %% [markdown]
# ### What is the ratio of "denials" to "approvals" for each record-type from the column "ethnicity_race_sex"?

# %%
# we are going to calculate the % of denial against approval for each record-type
scenarios = [
    "not hispanic or latino_white_male",
    "not hispanic or latino_white_female",
    "not hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application",
    "not hispanic or latino_white_not applicable",
    "not hispanic or latino_black or african american_male",
    "not hispanic or latino_black or african american_female",
    "not hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application",
    "not hispanic or latino_asian_male",
    "not hispanic or latino_asian_female",
    "not hispanic or latino_asian_information not provided by applicant in mail, internet, or telephone application",
    "not hispanic or latino_asian_not applicable",
    "not hispanic or latino_american indian or alaska native_male",
    "not hispanic or latino_american indian or alaska native_female",
    "not hispanic or latino_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application",
    "not hispanic or latino_native hawaiian or other pacific islander_male",
    "not hispanic or latino_native hawaiian or other pacific islander_female",
    "hispanic or latino_white_male",
    "hispanic or latino_white_female",
    "hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application",
    "hispanic or latino_black or african american_male",
    "hispanic or latino_black or african american_female",
    "hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application",
    "hispanic or latino_asian_male",
    "hispanic or latino_asian_female",
    "hispanic or latino_native hawaiian or other pacific islander_male",
    "hispanic or latino_native hawaiian or other pacific islander_female",
    "hispanic or latino_american indian or alaska native_male",
    "hispanic or latino_american indian or alaska native_female",
    "information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application",
    "information not provided by applicant in mail, internet, or telephone application_male",
    "information not provided by applicant in mail, internet, or telephone application_female",
    "information not provided by applicant in mail, internet, or telephone application_white_male",
    "information not provided by applicant in mail, internet, or telephone application_white_female",
    "information not provided by applicant in mail, internet, or telephone application_white_information not provided by applicant in mail, internet, or telephone application",
    "information not provided by applicant in mail, internet, or telephone application_black or african american_male",
    "information not provided by applicant in mail, internet, or telephone application_black or african american_female",
    "information not provided by applicant in mail, internet, or telephone application_black or african american_information not provided by applicant in mail, internet, or telephone application",
    "information not provided by applicant in mail, internet, or telephone application_asian_male",
    "information not provided by applicant in mail, internet, or telephone application_asian_female",
    "information not provided by applicant in mail, internet, or telephone application_asian_information not provided by applicant in mail, internet, or telephone application",
    "information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_male",
    "information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_female",
    "information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application",
    "information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_male",
    "information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_female",
    "not applicable_white_male",
    "not applicable_white_female",
    "not applicable_white_not applicable",
    "not applicable_black or african american_male",
    "not applicable_black or african american_female",
    "not applicable_asian_male",
    "not applicable_asian_female",
    "not applicable_not applicable_not applicable",
    "not applicable_not applicable_male",
    "not applicable_not applicable_female",
    "not applicable_information not provided by applicant in mail, internet, or telephone application_male",
    "not applicable_information not provided by applicant in mail, internet, or telephone application_female",
    "not applicable_information not provided by applicant in mail, internet, or telephone application_not applicable",
    "not applicable_not applicable_information not provided by applicant in mail, internet, or telephone application",
    "not applicable_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application"
]


# Dictionary to store results
ratios = {}

# Calculate the ratio for each record-case and store the results in the previous dictionary
for scenario in scenarios:
    # Filtering data
    scenarios_df = df[df['ethnicity_race_sex'] == scenario]
    
    # Counting
    approved_count = scenarios_df[scenarios_df['action_taken'] == "approved"].shape[0]  # Shape[]; to match our target
    denied_count = scenarios_df[scenarios_df['action_taken'] == "denied"].shape[0]
    
    # Calculate the ratio of "denied" to "approved"
    if approved_count == 0:  # Avoid division by zero
        ratio = None
    else:
        ratio = denied_count / approved_count
    
    # Store the result
    ratios[scenario] = ratio

# Print the results
for scenario, ratio in ratios.items():
    print(f"Ratio of 'Application denied' to 'approved' for '{scenario}': {ratio}")
# Out:
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_male': 0.2345311778290993
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_female': 0.24068626023127784
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application': 0.2605042016806723
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_not applicable': 0.25
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_black or african american_male': 0.5211267605633803
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_black or african american_female': 0.503062787136294
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application': 1.2
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_male': 0.2380381180860989
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_female': 0.22051479062620052
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_information not provided by applicant in mail, internet, or telephone application': 0.4117647058823529
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_not applicable': 0.0
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_american indian or alaska native_male': 0.592057761732852
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_american indian or alaska native_female': 0.6175115207373272
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application': 0.2
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_native hawaiian or other pacific islander_male': 0.5443037974683544
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_native hawaiian or other pacific islander_female': 0.41228070175438597
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_white_male': 0.33599137931034484
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_white_female': 0.35200311162971604
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_white_information not provided by applicant in mail, internet, or telephone application': 0.5
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_black or african american_male': 0.7564766839378239
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_black or african american_female': 0.6946902654867256
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_black or african american_information not provided by applicant in mail, internet, or telephone application': None
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_asian_male': 0.5434782608695652
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_asian_female': 0.41025641025641024
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_native hawaiian or other pacific islander_male': 1.2444444444444445
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_native hawaiian or other pacific islander_female': 1.1071428571428572
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_american indian or alaska native_male': 1.2083333333333333
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_american indian or alaska native_female': 1.0
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application': 0.46547711404189296
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_male': None
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_female': None
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_white_male': 0.5144312393887945
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_white_female': 0.6016483516483516
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_white_information not provided by applicant in mail, internet, or telephone application': 0.5686274509803921
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_black or african american_male': 1.2222222222222223
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_black or african american_female': 1.025
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_black or african american_information not provided by applicant in mail, internet, or telephone application': 1.4285714285714286
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_asian_male': 0.7794117647058824
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_asian_female': 0.37037037037037035
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_asian_information not provided by applicant in mail, internet, or telephone application': 1.5
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_male': 1.75
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_female': 1.25
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_american indian or alaska native_information not provided by applicant in mail, internet, or telephone application': 0.5
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_male': 1.0
# Ratio of 'Application denied' to 'approved' for 'information not provided by applicant in mail, internet, or telephone application_native hawaiian or other pacific islander_female': None
# Ratio of 'Application denied' to 'approved' for 'not applicable_white_male': 0.38095238095238093
# Ratio of 'Application denied' to 'approved' for 'not applicable_white_female': 0.6428571428571429
# Ratio of 'Application denied' to 'approved' for 'not applicable_white_not applicable': 0.0
# Ratio of 'Application denied' to 'approved' for 'not applicable_black or african american_male': 0.2
# Ratio of 'Application denied' to 'approved' for 'not applicable_black or african american_female': 0.3333333333333333
# Ratio of 'Application denied' to 'approved' for 'not applicable_asian_male': 0.0
# Ratio of 'Application denied' to 'approved' for 'not applicable_asian_female': None
# Ratio of 'Application denied' to 'approved' for 'not applicable_not applicable_not applicable': 0.11364485981308411
# Ratio of 'Application denied' to 'approved' for 'not applicable_not applicable_male': 0.3333333333333333
# Ratio of 'Application denied' to 'approved' for 'not applicable_not applicable_female': 0.5
# Ratio of 'Application denied' to 'approved' for 'not applicable_information not provided by applicant in mail, internet, or telephone application_male': 0.7777777777777778
# Ratio of 'Application denied' to 'approved' for 'not applicable_information not provided by applicant in mail, internet, or telephone application_female': 0.16666666666666666
# Ratio of 'Application denied' to 'approved' for 'not applicable_information not provided by applicant in mail, internet, or telephone application_not applicable': 0.0
# Ratio of 'Application denied' to 'approved' for 'not applicable_not applicable_information not provided by applicant in mail, internet, or telephone application': 0.0
# Ratio of 'Application denied' to 'approved' for 'not applicable_information not provided by applicant in mail, internet, or telephone application_information not provided by applicant in mail, internet, or telephone application': 0.4

# %% [markdown]
# #### What is the ratio of "denials" to "approvals" for each record-type from the column "ethnicity_race_sex" with no missing info ?

# %%
# we are going to calculate the % of denial against approval for each record-type
scenarios = ["not hispanic or latino_white_male",
            "not hispanic or latino_white_female",
            "not hispanic or latino_black or african american_male",
            "not hispanic or latino_black or african american_female",
            "not hispanic or latino_asian_male",
            "not hispanic or latino_asian_female",
            "not hispanic or latino_american indian or alaska native_male",
            "not hispanic or latino_american indian or alaska native_female",
            "not hispanic or latino_native hawaiian or other pacific islander_male",
            "not hispanic or latino_native hawaiian or other pacific islander_female",
            "hispanic or latino_white_male",
            "hispanic or latino_white_female",
            "hispanic or latino_black or african american_male",
            "hispanic or latino_black or african american_female",
            "hispanic or latino_asian_male",
            "hispanic or latino_asian_female",
            "hispanic or latino_native hawaiian or other pacific islander_male",
            "hispanic or latino_native hawaiian or other pacific islander_female",
            "hispanic or latino_american indian or alaska native_male",
            "hispanic or latino_american indian or alaska native_female"
            ]


# Dictionary to store results
ratios = {}

# Calculate the ratio for each record-case and store the results
for scenario in scenarios:
    # Filtering data
    scenarios_df = df[df['ethnicity_race_sex'] == scenario]
    
    # Counting
    approved_count = scenarios_df[scenarios_df['action_taken'] == "approved"].shape[0]  # Shape[]; to match our target
    denied_count = scenarios_df[scenarios_df['action_taken'] == "denied"].shape[0]
    
    # Calculate the ratio of "denied" to "approved"
    if approved_count == 0:  # Avoid division by zero
        ratio = None
    else:
        ratio = denied_count / approved_count
    
    # Store the result
    ratios[scenario] = ratio

# Print the results
for scenario, ratio in ratios.items():
    print(f"Ratio of 'Application denied' to 'approved' for '{scenario}': {ratio}")
# Out:
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_male': 0.2345311778290993
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_white_female': 0.24068626023127784
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_black or african american_male': 0.5211267605633803
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_black or african american_female': 0.503062787136294
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_male': 0.2380381180860989
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_asian_female': 0.22051479062620052
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_american indian or alaska native_male': 0.592057761732852
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_american indian or alaska native_female': 0.6175115207373272
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_native hawaiian or other pacific islander_male': 0.5443037974683544
# Ratio of 'Application denied' to 'approved' for 'not hispanic or latino_native hawaiian or other pacific islander_female': 0.41228070175438597
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_white_male': 0.33599137931034484
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_white_female': 0.35200311162971604
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_black or african american_male': 0.7564766839378239
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_black or african american_female': 0.6946902654867256
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_asian_male': 0.5434782608695652
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_asian_female': 0.41025641025641024
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_native hawaiian or other pacific islander_male': 1.2444444444444445
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_native hawaiian or other pacific islander_female': 1.1071428571428572
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_american indian or alaska native_male': 1.2083333333333333
# Ratio of 'Application denied' to 'approved' for 'hispanic or latino_american indian or alaska native_female': 1.0

# %% [markdown]
# # E) Excluding
# missing information from ethnicity_race_sex

# %%
# Target ethnicity_race_sex not affected by missing information
ethnicity_race_sex = [
    "not hispanic or latino_white_male",
    "not hispanic or latino_white_female",
    "not hispanic or latino_black or african american_male",
    "not hispanic or latino_black or african american_female",
    "not hispanic or latino_asian_male",
    "not hispanic or latino_asian_female",
    "not hispanic or latino_american indian or alaska native_male",
    "not hispanic or latino_american indian or alaska native_female",
    "not hispanic or latino_native hawaiian or other pacific islander_male",
    "not hispanic or latino_native hawaiian or other pacific islander_female",
    "hispanic or latino_white_male",
    "hispanic or latino_white_female",
    "hispanic or latino_black or african american_male",
    "hispanic or latino_black or african american_female",
    "hispanic or latino_asian_male",
    "hispanic or latino_asian_female",
    "hispanic or latino_native hawaiian or other pacific islander_male",
    "hispanic or latino_native hawaiian or other pacific islander_female",
    "hispanic or latino_american indian or alaska native_male",
    "hispanic or latino_american indian or alaska native_female"
]


df = df[df['ethnicity_race_sex'].isin(ethnicity_race_sex)]

# %%
print(df.columns)
# Out:
# Index(['loan_type_name', 'property_type_name', 'loan_purpose_name',
#        'loan_amount_000s', 'action_taken', 'msamd_name',
#        'applicant_ethnicity_name', 'applicant_race_name_1',
#        'applicant_sex_name', 'applicant_income_000s', 'denial_reason_name_1',
#        'denial_reason_name_2', 'denial_reason_name_3', 'rate_spread',
#        'lien_status_name', 'minority_population', 'hud_median_family_income',
#        'tract_to_msamd_income', 'ethnicity_race_sex'],
#       dtype='object')

# %%
# Saving .csv file
df.to_csv('C:/Users/nonox/hmdaNY29082024_1407_2.csv', index=False)

print(f"Dataset saved to '{'C:/Users/nonox/hmdaNY29082024_1407_2.csv'}'")
# Out:
# Dataset saved to 'C:/Users/nonox/hmdaNY29082024_1407_2.csv'

# %%
df = pd.read_csv('C:/Users/nonox/hmdaNY29082024_1407_2.csv')

# Print the values for each record of each column
for column in df:
    print(f"Distinct records and their counts for '{column}':")
    print(df[column].value_counts())
    print("\n" + "=+"*50 + "\n")
# Out:
# Distinct records and their counts for 'loan_type_name':
# loan_type_name
# Conventional          121855
# FHA-insured            23074
# VA-guaranteed           5406
# FSA/RHS-guaranteed      1280
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'property_type_name':
# property_type_name
# One-to-four family dwelling (other than manufactured housing)    147493
# Manufactured housing                                               3937
# Multifamily dwelling                                                185
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_purpose_name':
# loan_purpose_name
# Home purchase       82659
# Refinancing         45803
# Home improvement    23153
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'loan_amount_000s':
# loan_amount_000s
# 10       2509
# 5        1984
# 100      1772
# 15       1429
# 50       1407
# 200      1321
# 20       1269
# 8        1188
# 3        1187
# 25       1183
# 150      1137
# 300      1128
# 60        973
# 424       966
# 30        956
# 120       947
# 4         930
# 250       911
# 2         889
# 80        883
# 6         865
# 400       792
# 40        791
# 75        783
# 90        764
# 70        753
# 125       748
# 140       729
# 7         723
# 130       714
# 110       647
# 85        629
# 350       627
# 180       623
# 160       617
# 108       610
# 88        602
# 128       594
# 135       589
# 95        573
# 280       568
# 65        562
# 104       557
# 636       554
# 112       537
# 68        534
# 240       528
# 105       520
# 35        505
# 116       504
# 500       501
# 260       501
# 76        498
# 124       497
# 115       496
# 98        490
# 92        487
# 220       487
# 83        483
# 78        480
# 45        477
# 132       465
# 225       458
# 72        455
# 136       451
# 360       449
# 81        447
# 86        446
# 96        445
# 175       442
# 12        441
# 144       441
# 170       439
# 55        439
# 123       439
# 114       434
# 152       434
# 64        432
# 82        430
# 450       430
# 320       429
# 126       428
# 113       417
# 102       416
# 118       415
# 600       415
# 190       414
# 155       412
# 117       410
# 210       409
# 122       406
# 93        403
# 106       400
# 77        397
# 109       395
# 142       393
# 420       390
# 138       390
# 270       388
# 1         384
# 62        382
# 133       382
# 165       381
# 84        381
# 56        379
# 74        377
# 94        376
# 275       375
# 99        371
# 145       370
# 162       370
# 148       369
# 71        368
# 417       367
# 119       366
# 67        364
# 69        361
# 230       361
# 143       356
# 103       356
# 137       355
# 63        353
# 101       348
# 61        348
# 97        347
# 87        346
# 107       346
# 176       345
# 52        343
# 195       342
# 58        342
# 157       341
# 73        340
# 158       337
# 340       337
# 66        337
# 146       336
# 156       336
# 172       334
# 9         333
# 147       331
# 38.0       1387
# 35.0       1385
# 85.0       1383
# 90.0       1380
# 43.0       1364
# 51.0       1357
# 66.0       1348
# 37.0       1341
# 59.0       1310
# 63.0       1301
# 78.0       1294
# 68.0       1293
# 67.0       1282
# 64.0       1272
# 100.0      1265
# 41.0       1263
# 39.0       1231
# 34.0       1220
# 61.0       1213
# 73.0       1205
# 71.0       1194
# 31.0       1173
# 30.0       1170
# 69.0       1139
# 32.0       1119
# 33.0       1107
# 74.0       1104
# 77.0       1080
# 82.0       1078
# 95.0       1065
# 84.0       1058
# 76.0       1048
# 83.0       1026
# 79.0       1005
# 86.0        989
# 120.0       986
# 29.0        954
# 87.0        951
# 88.0        945
# 92.0        930
# 81.0        912
# 89.0        912
# 96.0        872
# 110.0       866
# 94.0        853
# 91.0        852
# 28.0        846
# 93.0        845
# 98.0        812
# 105.0       803
# 25.0        798
# 27.0        798
# 102.0       784
# 97.0        742
# 104.0       730
# 26.0        720
# 24.0        711
# 101.0       698
# 115.0       691
# 125.0       690
# 108.0       685
# 103.0       677
# 150.0       624
# 99.0        623
# 107.0       621
# 130.0       614
# 23.0        612
# 109.0       598
# 106.0       578
# 114.0       551
# 22.0        546
# 21.0        534
# 112.0       531
# 111.0       531
# 113.0       515
# 140.0       508
# 118.0       507
# 135.0       483
# 117.0       477
# 116.0       475
# 20.0        475
# 122.0       447
# 121.0       445
# 119.0       442
# 124.0       437
# 127.0       423
# 126.0       421
# 123.0       419
# 132.0       402
# 128.0       401
# 19.0        383
# 200.0       383
# 18.0        366
# 129.0       366
# 180.0       344
# 160.0       341
# 131.0       330
# 133.0       330
# 145.0       323
# 134.0       321
# 144.0       320
# 17.0        313
# 137.0       304
# 16.0        301
# 175.0       300
# 138.0       291
# 155.0       290
# 15.0        285
# 139.0       273
# 136.0       267
# 165.0       264
# 250.0       263
# 156.0       252
# 143.0       251
# 146.0       248
# 170.0       248
# 142.0       242
# 14.0        241
# 141.0       232
# 147.0       224
# 148.0       223
# 13.0        213
# 152.0       207
# 300.0       202
# 12.0        201
# 190.0       200
# 153.0       200
# 185.0       197
# 149.0       192
# 151.0       187
# 158.0       185
# 157.0       179
# 154.0       176
# 210.0       172
# 162.0       165
# 166.0       163
# 240.0       162
# 225.0       161
# 163.0       158
# 164.0       152
# 159.0       151
# 174.0       147
# 168.0       145
# 195.0       144
# 161.0       142
# 11.0        140
# 173.0       137
# 10.0        136
# 176.0       135
# 172.0       133
# 181.0       128
# 167.0       127
# 171.0       127
# 220.0       125
# 177.0       123
# 169.0       122
# 9.0         120
# 191.0       119
# 182.0       116
# 192.0       116
# 187.0       115
# 179.0       110
# 188.0       110
# 400.0       107
# 230.0       107
# 189.0       106
# 350.0       106
# 198.0       104
# 216.0        99
# 205.0        99
# 178.0        98
# 197.0        98
# 275.0        98
# 183.0        97
# 193.0        97
# 204.0        97
# 184.0        96
# 186.0        96
# 215.0        95
# 202.0        92
# 1.0          90
# 194.0        89
# 196.0        87
# 212.0        86
# 206.0        86
# 235.0        85
# 208.0        80
# 260.0        80
# 199.0        77
# 270.0        76
# 245.0        76
# 358.0        14
# 458.0        14
# 647.0        14
# 443.0        14
# 650.0        14
# 428.0        14
# 435.0        14
# 388.0        14
# 404.0        14
# 385.0        13
# 467.0        13
# 413.0        13
# 561.0        13
# 378.0        13
# 455.0        13
# 346.0        13
# 444.0        13
# 417.0        13
# 354.0        13
# 520.0        12
# 437.0        12
# 523.0        12
# 402.0        12
# 510.0        12
# 429.0        12
# 334.0        12
# 414.0        12
# 382.0        12
# 9999.0       12
# 465.0        12
# 463.0        12
# 389.0        12
# 368.0        12
# 539.0        12
# 1000.0       12
# 720.0        12
# 439.0        12
# 490.0        12
# 342.0        11
# 900.0        11
# 488.0        11
# 474.0        11
# 459.0        11
# 537.0        11
# 433.0        11
# 436.0        11
# 477.0        11
# 376.0        11
# 456.0        11
# 470.0        11
# 357.0        11
# 394.0        11
# 485.0        11
# 452.0        11
# 575.0        10
# 560.0        10
# 501.0        10
# 401.0        10
# 351.0        10
# 461.0        10
# 471.0        10
# 615.0        10
# 479.0        10
# 1200.0       10
# 508.0        10
# 460.0        10
# 1141.0       10
# 529.0        10
# 440.0        10
# 406.0        10
# 565.0        10
# 469.0        10
# 513.0        10
# 418.0         9
# 481.0         9
# 518.0         9
# 449.0         9
# 491.0         9
# 514.0         9
# 496.0         9
# 451.0         9
# 875.0         9
# 1500.0        9
# 462.0         9
# 457.0         9
# 419.0         9
# 675.0         9
# 399.0         9
# 506.0         9
# 651.0         9
# 495.0         9
# 521.0         9
# 598.0         9
# 660.0         9
# 438.0         9
# 421.0         9
# 472.0         9
# 540.0         9
# 515.0         9
# 447.0         9
# 850.0         9
# 547.0         8
# 422.0         8
# 606.0         8
# 535.0         8
# 566.0         8
# 546.0         8
# 536.0         8
# 576.0         8
# 545.0         8
# 541.0         8
# 497.0         8
# 583.0         8
# 431.0         8
# 441.0         8
# 552.0         8
# 464.0         8
# 411.0         8
# 585.0         8
# 596.0         8
# 634.0         8
# 363.0         8
# 568.0         8
# 504.0         8
# 373.0         8
# 442.0         8
# 524.0         8
# 494.0         8
# 484.0         8
# 581.0         7
# 551.0         7
# 793.0         7
# 533.0         7
# 580.0         7
# 478.0         7
# 468.0         7
# 530.0         7
# 527.0         7
# 800.0         7
# 492.0         7
# 594.0         7
# 487.0         7
# 593.0         7
# 618.0         7
# 427.0         7
# 564.0         7
# 673.0         7
# 572.0         7
# 712.0         7
# 636.0         7
# 624.0         7
# 739.0         7
# 499.0         7
# 589.0         7
# 662.0         7
# 445.0         7
# 733.0         7
# 483.0         7
# 493.0         7
# 528.0         7
# 553.0         7
# 509.0         7
# 640.0         7
# 453.0         7
# 542.0         7
# 614.0         7
# 761.0         6
# 617.0         6
# 611.0         6
# 775.0         6
# 959.0         6
# 705.0         6
# 787.0         6
# 526.0         6
# 610.0         6
# 503.0         6
# 555.0         6
# 2679.0        6
# 482.0         6
# 519.0         6
# 505.0         6
# 644.0         6
# 726.0         6
# 590.0         6
# 630.0         6
# 489.0         6
# 426.0         6
# 633.0         6
# 1020.0        6
# 831.0         6
# 423.0         6
# 672.0         6
# 677.0         6
# 604.0         6
# 586.0         6
# 653.0         6
# 612.0         6
# 517.0         6
# 746.0         6
# 538.0         6
# 448.0         6
# 516.0         6
# 684.0         6
# 543.0         6
# 725.0         6
# 707.0         5
# 629.0         5
# 563.0         5
# 558.0         5
# 665.0         5
# 595.0         5
# 511.0         5
# 582.0         5
# 1107.0        5
# 678.0         5
# 888.0         5
# 577.0         5
# 597.0         5
# 772.0         5
# 848.0         5
# 559.0         5
# 698.0         5
# 832.0         5
# 626.0         5
# 599.0         5
# 1271.0        5
# 486.0         5
# 454.0         5
# 602.0         5
# 637.0         5
# 1013.0        5
# 1400.0        5
# 679.0         5
# 840.0         5
# 570.0         5
# 554.0         5
# 723.0         5
# 699.0         5
# 613.0         5
# 502.0         5
# 2000.0        5
# 648.0         5
# 632.0         5
# 3697.0        5
# 1100.0        5
# 512.0         5
# 2612.0        5
# 549.0         5
# 983.0         5
# 1256.0        5
# 689.0         5
# 760.0         5
# 605.0         5
# 476.0         5
# 498.0         5
# 859.0         5
# 797.0         5
# 544.0         5
# 446.0         5
# 764.0         5
# 562.0         5
# 732.0         5
# 811.0         5
# 1030.0        4
# 556.0         4
# 1800.0        4
# 1294.0        4
# 835.0         4
# 812.0         4
# 724.0         4
# 988.0         4
# 785.0         4
# 893.0         4
# 860.0         4
# 711.0         4
# 674.0         4
# 701.0         4
# 691.0         4
# 587.0         4
# 909.0         4
# 790.0         4
# 681.0         4
# 1222.0        4
# 627.0         4
# 950.0         4
# 1322.0        4
# 687.0         4
# 1054.0        4
# 573.0         4
# 846.0         4
# 773.0         4
# 753.0         4
# 688.0         4
# 769.0         4
# 631.0         4
# 522.0         4
# 756.0         4
# 1008.0        4
# 728.0         4
# 802.0         4
# 694.0         4
# 621.0         4
# 1114.0        4
# 579.0         4
# 1028.0        4
# 1084.0        4
# 782.0         4
# 816.0         4
# 655.0         4
# 696.0         4
# 796.0         4
# 704.0         4
# 798.0         4
# 741.0         4
# 930.0         4
# 588.0         4
# 571.0         4
# 1276.0        4
# 3088.0        3
# 1079.0        3
# 686.0         3
# 616.0         3
# 902.0         3
# 815.0         3
# 1376.0        3
# 1035.0        3
# 771.0         3
# 813.0         3
# 4420.0        3
# 727.0         3
# 603.0         3
# 1380.0        3
# 867.0         3
# 1201.0        3
# 1095.0        3
# 933.0         3
# 1205.0        3
# 906.0         3
# 936.0         3
# 932.0         3
# 1340.0        3
# 548.0         3
# 913.0         3
# 744.0         3
# 710.0         3
# 754.0         3
# 794.0         3
# 532.0         3
# 854.0         3
# 649.0         3
# 507.0         3
# 843.0         3
# 758.0         3
# 962.0         3
# 645.0         3
# 680.0         3
# 1457.0        3
# 1860.0        3
# 591.0         3
# 1167.0        3
# 823.0         3
# 810.0         3
# 1237.0        3
# 1019.0        3
# 911.0         3
# 747.0         3
# 889.0         3
# 759.0         3
# 879.0         3
# 1080.0        3
# 1358.0        3
# 738.0         3
# 2307.0        3
# 765.0         3
# 1722.0        3
# 661.0         3
# 955.0         3
# 817.0         3
# 1310.0        3
# 473.0         3
# 1197.0        3
# 709.0         3
# 670.0         3
# 69.519997       11
# 31.040001       11
# 59.930000       11
# 137.250000      11
# 136.429993      11
# 39.060001       11
# 49.380001       11
# 58.060001       11
# 37.389999       11
# 53.770000       11
# 74.540001       11
# 76.529999       11
# 77.900002       11
# 64.279999       11
# 31.780001       11
# 87.410004       11
# 86.250000       11
# 132.399994      11
# 56.009998       11
# 64.699997       11
# 130.990005      11
# 113.809998      11
# 77.879997       11
# 93.680000       11
# 51.660000       11
# 139.490005      11
# 54.439999       11
# 54.000000       11
# 52.680000       11
# 224.330002      11
# 79.459999       11
# 152.889999      11
# 111.809998      11
# 93.400002       11
# 65.500000       11
# 66.540001       11
# 106.449997      11
# 45.060001       11
# 68.820000       11
# 32.380001       11
# 139.520004      11
# 92.500000       11
# 47.639999       11
# 51.380001       11
# 55.020000       10
# 280.100006      10
# 111.570000      10
# 67.589996       10
# 88.500000       10
# 125.610001      10
# 61.410000       10
# 42.869999       10
# 118.300003      10
# 151.710007      10
# 84.959999       10
# 185.270004      10
# 196.919998      10
# 97.500000       10
# 91.650002       10
# 45.150002       10
# 35.020000       10
# 84.260002       10
# 78.029999       10
# 30.600000       10
# 47.060001       10
# 130.119995      10
# 49.939999       10
# 92.949997       10
# 70.029999       10
# 122.309998      10
# 96.970001       10
# 116.739998      10
# 84.400002       10
# 84.849998       10
# 167.529999      10
# 79.660004       10
# 64.879997       10
# 60.689999       10
# 32.299999       10
# 99.760002       10
# 91.470001       10
# 51.610001       10
# 45.590000       10
# 24.940001       10
# 158.660004      10
# 61.680000       10
# 88.400002       10
# 45.360001       10
# 48.709999       10
# 40.590000       10
# 68.019997       10
# 80.459999       10
# 50.860001       10
# 127.230003      10
# 82.820000       10
# 43.279999       10
# 67.970001       10
# 61.990002       10
# 102.230003      10
# 45.029999       10
# 75.559998       10
# 231.220001      10
# 36.430000       10
# 130.059998      10
# 75.129997       10
# 81.910004       10
# 40.610001       10
# 25.510000       10
# 27.160000       10
# 36.509998       10
# 135.440002      10
# 95.010002        9
# 41.849998        9
# 20.379999        9
# 58.250000        9
# 154.710007       9
# 92.260002        9
# 69.699997        9
# 70.309998        9
# 87.180000        9
# 45.970001        9
# 84.599998        9
# 55.820000        9
# 38.290001        9
# 48.310001        9
# 139.339996       9
# 48.790001        9
# 63.470001        9
# 42.939999        9
# 34.250000        9
# 49.560001        9
# 39.730000        9
# 63.570000        9
# 337.160004       9
# 42.580002        9
# 38.029999        9
# 75.449997        9
# 70.669998        9
# 91.660004        9
# 103.230003       9
# 49.950001        9
# 125.150002       9
# 213.399994       9
# 73.019997        9
# 83.459999        9
# 118.430000       9
# 66.669998        9
# 44.849998        9
# 61.279999        9
# 110.809998       9
# 92.680000        9
# 243.220001       9
# 61.299999        9
# 34.599998        9
# 55.169998        9
# 65.629997        9
# 56.340000        9
# 141.899994       9
# 61.980000        9
# 71.779999        9
# 114.019997       9
# 102.430000       9
# 145.589996       9
# 152.669998       9
# 125.529999       9
# 127.360001       9
# 47.770000        9
# 97.989998        9
# 67.629997        9
# 66.410004        9
# 204.470001       9
# 125.900002       9
# 160.600006       9
# 39.790001        9
# 88.650002        9
# 72.309998        9
# 51.970001        9
# 110.430000       9
# 116.900002       9
# 127.080002       9
# 122.660004       9
# 74.099998        9
# 53.080002        8
# 116.050003       8
# 55.970001        8
# 62.090000        8
# 202.550003       8
# 98.000000        8
# 82.830002        8
# 146.190002       8
# 141.399994       8
# 38.689999        8
# 43.630001        8
# 180.710007       8
# 27.420000        8
# 81.629997        8
# 34.080002        8
# 80.559998        8
# 49.029999        8
# 224.139999       8
# 37.180000        8
# 44.360001        8
# 118.769997       8
# 104.959999       8
# 44.029999        8
# 59.849998        8
# 81.760002        8
# 33.570000        8
# 203.979996       8
# 147.050003       8
# 97.820000        8
# 146.770004       8
# 128.000000       8
# 43.549999        8
# 69.320000        8
# 58.869999        8
# 79.209999        8
# 75.989998        8
# 33.770000        8
# 202.699997       8
# 52.950001        8
# 135.130005       8
# 74.639999        8
# 89.839996        8
# 76.239998        8
# 315.760010       8
# 108.070000       8
# 24.410000        8
# 105.110001       8
# 125.949997       8
# 39.230000        8
# 78.989998        8
# 83.309998        8
# 43.430000        8
# 169.679993       8
# 65.139999        8
# 66.580002        8
# 100.949997       8
# 61.459999        8
# 85.540001        8
# 82.930000        8
# 42.480000        8
# 67.730003        8
# 151.809998       8
# 32.220001        8
# 71.400002        8
# 111.669998       8
# 76.440002        8
# 43.919998        8
# 85.519997        8
# 29.799999        8
# 42.770000        8
# 40.209999        8
# 45.619999        8
# 67.660004        8
# 50.840000        8
# 30.469999        8
# 42.750000        8
# 75.820000        8
# 28.090000        8
# 43.590000        8
# 59.360001        7
# 121.070000       7
# 37.790001        7
# 100.440002       7
# 65.860001        7
# 25.610001        7
# 43.169998        7
# 87.059998        7
# 98.620003        7
# 121.550003       7
# 58.849998        7
# 41.810001        7
# 41.630001        7
# 81.849998        7
# 103.349998       7
# 36.220001        7
# 99.620003        7
# 50.919998        7
# 160.869995       7
# 56.540001        7
# 41.450001        7
# 129.419998       7
# 44.070000        7
# 108.339996       7
# 63.770000        7
# 68.330002        7
# 173.110001       7
# 38.160000        7
# 238.839996       7
# 46.549999        7
# 58.369999        7
# 46.750000        7
# 29.860001        7
# 86.400002        7
# 60.389999        7
# 88.269997        7
# 51.259998        7
# 77.459999        7
# 133.050003       7
# 53.270000        7
# 34.980000        7
# 42.459999        7
# 59.770000        7
# 63.560001        7
# 100.279999       7
# 31.889999        7
# 27.730000        7
# 54.169998        7
# 176.449997       7
# 68.099998        7
# 120.860001       7
# 59.119999        7
# 136.869995       7
# 65.620003        7
# 72.419998        7
# 61.509998        7
# 77.320000        7
# 25.910000        7
# 120.510002       7
# 24.350000        7
# 109.730003       7
# 34.439999        7
# 65.400002        7
# 132.720001       7
# 80.019997        7
# 37.330002        7
# 270.649994       7
# 73.000000        7
# 110.930000       7
# 34.709999        7
# 49.400002        7
# 47.869999        7
# 88.730003        7
# 44.590000        7
# 28.270000        7
# 85.709999        6
# 41.799999        6
# 74.480003        6
# 31.080000        6
# 86.309998        6
# 88.940002        6
# 141.449997       6
# 47.330002        6
# 34.240002        6
# 22.070000        6
# 98.120003        6
# 30.490000        6
# 110.500000       6
# 52.820000        6
# 37.869999        6
# 36.930000        6
# 54.790001        6
# 85.720001        6
# 56.220001        6
# 140.929993       6
# 49.709999        6
# 42.520000        6
# 138.490005       6
# 56.730000        6
# 82.169998        6
# 50.209999        6
# 124.160004       6
# 55.730000        6
# 134.740005       6
# 37.590000        6
# 40.200001        6
# 44.230000        6
# 30.180000        6
# 71.820000        6
# 24.430000        6
# 148.449997       6
# 66.500000        6
# 30.129999        6
# 27.940001        6
# 41.959999        6
# 104.339996       6
# 115.430000       6
# 97.559998        6
# 39.900002        6
# 61.590000        6
# 56.619999        6
# 45.639999        6
# 92.330002        6
# 42.849998        6
# 37.560001        6
# 57.500000        6
# 48.290001        6
# 135.580002       6
# 73.300003        6
# 220.250000       6
# 122.379997       6
# 68.529999        6
# 40.090000        6
# 78.940002        6
# 72.620003        6
# 67.610001        6
# 20.730000        6
# 183.429993       6
# 48.740002        6
# 40.080002        6
# 82.080002        6
# 179.149994       5
# 37.680000        5
# 29.510000        5
# 77.519997        5
# 47.650002        5
# 78.300003        5
# 43.770000        5
# 119.870003       5
# 32.790001        5
# 318.649994       5
# 144.910004       5
# 52.209999        5
# 89.519997        5
# 59.330002        5
# 57.750000        5
# 36.730000        5
# 42.959999        5
# 56.650002        5
# 27.520000        5
# 208.559998       5
# 73.940002        5
# 44.930000        5
# 75.959999        5
# 134.020004       5
# 35.230000        5
# 39.740002        5
# 71.449997        5
# 60.990002        5
# 64.389999        5
# 58.230000        5
# 28.330000        5
# 45.669998        5
# 59.340000        5
# 52.310001        5
# 88.029999        5
# 28.219999        5
# 49.919998        5
# 113.459999       5
# 66.220001        5
# 63.740002        5
# 95.529999        5
# 82.300003        5
# 46.759998        5
# 133.779999       5
# 48.450001        5
# 92.349998        5
# 60.880001        5
# 25.760000        5
# 22.730000        5
# 29.240000        5
# 55.860001        5
# 69.580002        5
# 40.869999        5
# 65.599998        5
# 36.400002        5
# 42.360001        5
# 45.930000        5
# 61.009998        5
# 29.250000        5
# 37.810001        5
# 40.360001        5
# 82.230003        5
# 216.869995       5
# 47.980000        5
# 41.230000        4
# 47.259998        4
# 48.860001        4
# 56.060001        4
# 60.669998        4
# 54.410000        4
# 50.730000        4
# 154.059998       4
# 32.830002        4
# 96.739998        4
# 44.320000        4
# 21.379999        4
# 55.959999        4
# 33.849998        4
# 180.910004       4
# 79.070000        4
# 35.000000        4
# 33.070000        4
# 60.820000        4
# 40.730000        4
# 107.639999       4
# 64.110001        4
# 59.689999        4
# 47.970001        4
# 70.959999        4
# 103.760002       4
# 57.849998        4
# 135.839996       4
# 91.639999        4
# 73.980003        4
# 37.750000        4
# 39.639999        4
# 28.120001        4
# 133.360001       4
# 46.400002        4
# 77.339996        4
# 188.589996       4
# 43.799999        4
# 140.899994       4
# 108.209999       4
# 47.599998        4
# 69.190002        4
# 72.250000        4
# 179.759995       4
# 170.380005       4
# 84.589996        4
# 32.639999        4
# 104.470001       4
# 28.930000        4
# 44.990002        4
# 31.770000        4
# 155.320007       4
# 52.320000        4
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# Distinct records and their counts for 'ethnicity_race_sex':
# ethnicity_race_sex
# not hispanic or latino_white_male                                          66819
# not hispanic or latino_white_female                                        42594
# not hispanic or latino_asian_male                                           9289
# not hispanic or latino_black or african american_female                     7852
# not hispanic or latino_black or african american_male                       6588
# not hispanic or latino_asian_female                                         6354
# hispanic or latino_white_male                                               6199
# hispanic or latino_white_female                                             3476
# not hispanic or latino_american indian or alaska native_male                 441
# hispanic or latino_black or african american_female                          383
# not hispanic or latino_american indian or alaska native_female               351
# hispanic or latino_black or african american_male                            339
# not hispanic or latino_native hawaiian or other pacific islander_male        244
# not hispanic or latino_native hawaiian or other pacific islander_female      161
# hispanic or latino_american indian or alaska native_male                     159
# hispanic or latino_native hawaiian or other pacific islander_male            101
# hispanic or latino_american indian or alaska native_female                    80
# hispanic or latino_asian_male                                                 71
# hispanic or latino_native hawaiian or other pacific islander_female           59
# hispanic or latino_asian_female                                               55
# Name: count, dtype: int64
#
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+

# %%
print(df.shape)
# Out:
# (151615, 19)

# %%
print(df.columns)
# Out:
# Index(['loan_type_name', 'property_type_name', 'loan_purpose_name',
#        'loan_amount_000s', 'action_taken', 'msamd_name',
#        'applicant_ethnicity_name', 'applicant_race_name_1',
#        'applicant_sex_name', 'applicant_income_000s', 'denial_reason_name_1',
#        'denial_reason_name_2', 'denial_reason_name_3', 'rate_spread',
#        'lien_status_name', 'minority_population', 'hud_median_family_income',
#        'tract_to_msamd_income', 'ethnicity_race_sex'],
#       dtype='object')

# %% [markdown]
# # F) More questions

# %% [markdown]
# #### Is there any relationship between missing values from minority_population and approval/denial rate?
# #
# #### What is the race?
# #

# %%
import pandas as pd

# Step 1: Checking for missing values in the 'minority_population' column
df['minority_population_missing'] = df['minority_population'].isnull()

# Step 2: Grouping the data by 'minority_population_missing', 'action_taken', and 'applicant_race_name_1'
grouped = df.groupby(['minority_population_missing', 'action_taken', 'ethnicity_race_sex']).size().unstack(fill_value=0)

# Step 3: Calculate the approval and denial rates
approval_rate = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Step 4: Display the results
print("Approval/Denial Rates by minority_population_missing and Race:")
print(approval_rate)
# Out:
# Approval/Denial Rates by minority_population_missing and Race:
# ethnicity_race_sex                        hispanic or latino_american indian or alaska native_female  \
# minority_population_missing action_taken
# False                       approved                                               0.033520
#                             denied                                                 0.124992
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_american indian or alaska native_male  \
# minority_population_missing action_taken
# False                       approved                                               0.060336
#                             denied                                                 0.271858
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_asian_female  \
# minority_population_missing action_taken
# False                       approved                             0.032682
#                             denied                               0.049997
# True                        approved                             0.000000
#                             denied                               0.000000
#
# ethnicity_race_sex                        hispanic or latino_asian_male  \
# minority_population_missing action_taken
# False                       approved                           0.038548
#                             denied                             0.078120
# True                        approved                           0.000000
#                             denied                             0.000000
#
# ethnicity_race_sex                        hispanic or latino_black or african american_female  \
# minority_population_missing action_taken
# False                       approved                                               0.189388
#                             denied                                                 0.490594
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_black or african american_male  \
# minority_population_missing action_taken
# False                       approved                                               0.161734
#                             denied                                                 0.456221
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_native hawaiian or other pacific islander_female  \
# minority_population_missing action_taken
# False                       approved                                               0.023464
#                             denied                                                 0.096869
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_native hawaiian or other pacific islander_male  \
# minority_population_missing action_taken
# False                       approved                                               0.037710
#                             denied                                                 0.174989
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        hispanic or latino_white_female  \
# minority_population_missing action_taken
# False                       approved                             2.154493
#                             denied                               2.827948
# True                        approved                             0.000000
#                             denied                               0.000000
#
# ethnicity_race_sex                        hispanic or latino_white_male  \
# minority_population_missing action_taken
# False                       approved                           3.885798
#                             denied                             4.859071
# True                        approved                           5.555556
#                             denied                             1.762115
#
# ethnicity_race_sex                        not hispanic or latino_american indian or alaska native_female  \
# minority_population_missing action_taken
# False                       approved                                               0.181846
#                             denied                                                 0.415599
# True                        approved                                               0.000000
#                             denied                                                 0.440529
#
# ethnicity_race_sex                        not hispanic or latino_american indian or alaska native_male  \
# minority_population_missing action_taken
# False                       approved                                               0.232125
#                             denied                                                 0.509343
# True                        approved                                               0.000000
#                             denied                                                 0.440529
#
# ethnicity_race_sex                        not hispanic or latino_asian_female  \
# minority_population_missing action_taken
# False                       approved                                 4.362619
#                             denied                                   3.587276
# True                        approved                                 0.000000
#                             denied                                   0.000000
#
# ethnicity_race_sex                        not hispanic or latino_asian_male  \
# minority_population_missing action_taken
# False                       approved                               6.287500
#                             denied                                 5.577776
# True                        approved                               0.000000
#                             denied                                 0.440529
#
# ethnicity_race_sex                        not hispanic or latino_black or african american_female  \
# minority_population_missing action_taken
# False                       approved                                               4.376027
#                             denied                                                 8.196363
# True                        approved                                               3.703704
#                             denied                                                 2.202643
#
# ethnicity_race_sex                        not hispanic or latino_black or african american_male  \
# minority_population_missing action_taken
# False                       approved                                               3.629370
#                             denied                                                 7.043310
# True                        approved                                               0.000000
#                             denied                                                 1.321586
#
# ethnicity_race_sex                        not hispanic or latino_native hawaiian or other pacific islander_female  \
# minority_population_missing action_taken
# False                       approved                                               0.094694
#                             denied                                                 0.146866
# True                        approved                                               1.851852
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        not hispanic or latino_native hawaiian or other pacific islander_male  \
# minority_population_missing action_taken
# False                       approved                                               0.132404
#                             denied                                                 0.268733
# True                        approved                                               0.000000
#                             denied                                                 0.000000
#
# ethnicity_race_sex                        not hispanic or latino_white_female  \
# minority_population_missing action_taken
# False                       approved                                28.751718
#                             denied                                  25.464033
# True                        approved                                38.888889
#                             denied                                  50.220264
#
# ethnicity_race_sex                        not hispanic or latino_white_male
# minority_population_missing action_taken
# False                       approved                              45.334026
#                             denied                                39.360040
# True                        approved                              50.000000
#                             denied                                43.171806

# %% [markdown]
# ### What is the ratio of applications of men vs women?

# %%
# Step 1: Count the number of applications for men and women
male_count = df[df['applicant_sex_name'] == 'Male'].shape[0]
female_count = df[df['applicant_sex_name'] == 'Female'].shape[0]

# Step 2: Calculate the ratio of men to women
if female_count == 0:  # Avoid division by zero
    ratio = None
else:
    ratio = female_count / male_count

# Step 3: Display the results
print(f"Number of applications by men: {male_count}")
print(f"Number of applications by women: {female_count}")
print(f"Ratio of applications (Men vs Women): {ratio}")
# Out:
# Number of applications by men: 90250
# Number of applications by women: 61365
# Ratio of applications (Men vs Women): 0.6799445983379502

# %% [markdown]
# ### How much is the average of the total loan amount asked per men vs women?

# %%
# Step 1: Filter the data for men and women
male_loans = df[df['applicant_sex_name'] == 'Male']['loan_amount_000s']
female_loans = df[df['applicant_sex_name'] == 'Female']['loan_amount_000s']

# Step 2: Calculate the average loan amount for men and women
average_male_loan = male_loans.mean()
average_female_loan = female_loans.mean()

# Step 3: Display the results
print(f"Average loan amount requested by men: ${average_male_loan:.2f} (in thousands)")
print(f"Average loan amount requested by women: ${average_female_loan:.2f} (in thousands)")
# Out:
# Average loan amount requested by men: $279.14 (in thousands)
# Average loan amount requested by women: $212.62 (in thousands)

# %% [markdown]
# ### What is the avg income per ethnicity, race, sex?

# %%
# Step 1: Group the data by 'ethnicity_race_sex' and calculate the average income
average_income_by_ethnicity_race_sex = df.groupby('ethnicity_race_sex')['applicant_income_000s'].mean()

# Step 2: Display the results
print("Average Applicant Income by Ethnicity, Race, and Sex:")
print(average_income_by_ethnicity_race_sex)
# Out:
# Average Applicant Income by Ethnicity, Race, and Sex:
# ethnicity_race_sex
# hispanic or latino_american indian or alaska native_female                  76.615385
# hispanic or latino_american indian or alaska native_male                    94.696296
# hispanic or latino_asian_female                                             82.377358
# hispanic or latino_asian_male                                              100.626866
# hispanic or latino_black or african american_female                         77.077151
# hispanic or latino_black or african american_male                           85.901316
# hispanic or latino_native hawaiian or other pacific islander_female         78.260000
# hispanic or latino_native hawaiian or other pacific islander_male           77.255319
# hispanic or latino_white_female                                             82.790662
# hispanic or latino_white_male                                              103.220159
# not hispanic or latino_american indian or alaska native_female              74.345277
# not hispanic or latino_american indian or alaska native_male                88.501235
# not hispanic or latino_asian_female                                        114.745182
# not hispanic or latino_asian_male                                          147.053146
# not hispanic or latino_black or african american_female                     81.773010
# not hispanic or latino_black or african american_male                       96.781492
# not hispanic or latino_native hawaiian or other pacific islander_female     89.671141
# not hispanic or latino_native hawaiian or other pacific islander_male      104.815789
# not hispanic or latino_white_female                                         85.986492
# not hispanic or latino_white_male                                          137.847332
# Name: applicant_income_000s, dtype: float64

# %% [markdown]
# ### What is the avg of "rate_spread" for each group?

# %%
# Step 1: Group the data by 'ethnicity_race_sex' and calculate the average rate spread
average_rate_spread_by_ethnicity_race_sex = df.groupby('ethnicity_race_sex')['rate_spread'].mean()

# Step 2: Display the results
print("Average Rate Spread by Ethnicity, Race, and Sex:")
print(average_rate_spread_by_ethnicity_race_sex)
# Out:
# Average Rate Spread by Ethnicity, Race, and Sex:
# ethnicity_race_sex
# hispanic or latino_american indian or alaska native_female                 1.555000
# hispanic or latino_american indian or alaska native_male                   1.600000
# hispanic or latino_asian_female                                            1.775000
# hispanic or latino_asian_male                                              1.830000
# hispanic or latino_black or african american_female                        2.178667
# hispanic or latino_black or african american_male                          1.990000
# hispanic or latino_native hawaiian or other pacific islander_female        2.200000
# hispanic or latino_native hawaiian or other pacific islander_male          1.626667
# hispanic or latino_white_female                                            2.126797
# hispanic or latino_white_male                                              2.123458
# not hispanic or latino_american indian or alaska native_female             3.936364
# not hispanic or latino_american indian or alaska native_male               2.935385
# not hispanic or latino_asian_female                                        2.497632
# not hispanic or latino_asian_male                                          2.545894
# not hispanic or latino_black or african american_female                    2.043282
# not hispanic or latino_black or african american_male                      2.200951
# not hispanic or latino_native hawaiian or other pacific islander_female    2.678000
# not hispanic or latino_native hawaiian or other pacific islander_male      2.988571
# not hispanic or latino_white_female                                        2.380007
# not hispanic or latino_white_male                                          2.339076
# Name: rate_spread, dtype: float64

# %% [markdown]
# ### Which group has the most empty cells in the column "rate_spread" which means they are not being overcharged)?

# %%
# Step 1: Group the data by 'ethnicity_race_sex' and count the null values in 'rate_spread'
null_rate_spread_by_ethnicity_race_sex = df.groupby('ethnicity_race_sex')['rate_spread'].apply(lambda x: x.isnull().sum())

# Step 2: Display the results
print("Null values in 'rate_spread' by Ethnicity, Race, and Sex:")
print(null_rate_spread_by_ethnicity_race_sex)
# Out:
# Null values in 'rate_spread' by Ethnicity, Race, and Sex:
# ethnicity_race_sex
# hispanic or latino_american indian or alaska native_female                    78
# hispanic or latino_american indian or alaska native_male                     157
# hispanic or latino_asian_female                                               53
# hispanic or latino_asian_male                                                 70
# hispanic or latino_black or african american_female                          368
# hispanic or latino_black or african american_male                            324
# hispanic or latino_native hawaiian or other pacific islander_female           58
# hispanic or latino_native hawaiian or other pacific islander_male             98
# hispanic or latino_white_female                                             3348
# hispanic or latino_white_male                                               5904
# not hispanic or latino_american indian or alaska native_female               340
# not hispanic or latino_american indian or alaska native_male                 428
# not hispanic or latino_asian_female                                         5919
# not hispanic or latino_asian_male                                           8797
# not hispanic or latino_black or african american_female                     7526
# not hispanic or latino_black or african american_male                       6304
# not hispanic or latino_native hawaiian or other pacific islander_female      156
# not hispanic or latino_native hawaiian or other pacific islander_male        237
# not hispanic or latino_white_female                                        41212
# not hispanic or latino_white_male                                          64763
# Name: rate_spread, dtype: int64

# %% [markdown]
# ###  What is the % of null cell compared to not null (not overcharged vs overcharged)?

# %%
# Step 1: Group the data by 'ethnicity_race_sex' and count the total number of rows and null values in 'rate_spread'
total_count_by_group = df.groupby('ethnicity_race_sex')['rate_spread'].count() + df.groupby('ethnicity_race_sex')['rate_spread'].apply(lambda x: x.isnull().sum())
null_count_by_group = df.groupby('ethnicity_race_sex')['rate_spread'].apply(lambda x: x.isnull().sum())

# Step 2: Calculate the percentage of null values for each group
percentage_null_by_group = (null_count_by_group / total_count_by_group) * 100

# Step 3: Display the results
print("Percentage of Null values in 'rate_spread' by Ethnicity, Race, and Sex:")
print(percentage_null_by_group)


#https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
#https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
#https://github.com/LDSSA/batch4-students
#https://www.geeksforgeeks.org/python-lambda-anonymous-functions-filter-map-reduce/
#https://realpython.com/python-lambda/
# Out:
# Percentage of Null values in 'rate_spread' by Ethnicity, Race, and Sex:
# ethnicity_race_sex
# hispanic or latino_american indian or alaska native_female                 97.500000
# hispanic or latino_american indian or alaska native_male                   98.742138
# hispanic or latino_asian_female                                            96.363636
# hispanic or latino_asian_male                                              98.591549
# hispanic or latino_black or african american_female                        96.083551
# hispanic or latino_black or african american_male                          95.575221
# hispanic or latino_native hawaiian or other pacific islander_female        98.305085
# hispanic or latino_native hawaiian or other pacific islander_male          97.029703
# hispanic or latino_white_female                                            96.317606
# hispanic or latino_white_male                                              95.241168
# not hispanic or latino_american indian or alaska native_female             96.866097
# not hispanic or latino_american indian or alaska native_male               97.052154
# not hispanic or latino_asian_female                                        93.153919
# not hispanic or latino_asian_male                                          94.703413
# not hispanic or latino_black or african american_female                    95.848192
# not hispanic or latino_black or african american_male                      95.689132
# not hispanic or latino_native hawaiian or other pacific islander_female    96.894410
# not hispanic or latino_native hawaiian or other pacific islander_male      97.131148
# not hispanic or latino_white_female                                        96.755412
# not hispanic or latino_white_male                                          96.923031
# Name: rate_spread, dtype: float64

# %%
# Group by 'ethnicity_race_sex' and 'applicant_sex_name', then count
result = df.groupby(['ethnicity_race_sex', 'applicant_sex_name']).size().unstack(fill_value=0)

# Rename columns for clarity
result = result.rename(columns={'Male': 'Total_Males', 'Female': 'Total_Females'})

# Sort by Total_Males in descending order (you can change this if needed)
result_sorted = result.sort_values('Total_Males', ascending=False)

# Display the results
print(result_sorted)

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unstack.html
# Out:
# applicant_sex_name                                  Total_Females  Total_Males
# ethnicity_race_sex
# not hispanic or latino_white_male                               0        66819
# not hispanic or latino_asian_male                               0         9289
# not hispanic or latino_black or african america...              0         6588
# hispanic or latino_white_male                                   0         6199
# not hispanic or latino_american indian or alask...              0          441
# hispanic or latino_black or african american_male               0          339
# not hispanic or latino_native hawaiian or other...              0          244
# hispanic or latino_american indian or alaska na...              0          159
# hispanic or latino_native hawaiian or other pac...              0          101
# hispanic or latino_asian_male                                   0           71
# not hispanic or latino_white_female                         42594            0
# not hispanic or latino_native hawaiian or other...            161            0
# not hispanic or latino_black or african america...           7852            0
# hispanic or latino_american indian or alaska na...             80            0
# not hispanic or latino_asian_female                          6354            0
# hispanic or latino_white_female                              3476            0
# hispanic or latino_native hawaiian or other pac...             59            0
# hispanic or latino_black or african american_fe...            383            0
# hispanic or latino_asian_female                                55            0
# not hispanic or latino_american indian or alask...            351            0

# %%
# Group by 'ethnicity_race_sex' and 'applicant_sex_name', then count
result = df.groupby(['ethnicity_race_sex', 'applicant_sex_name']).size().unstack(fill_value=0)

# Rename columns for clarity
result = result.rename(columns={'Male': 'Total_Males', 'Female': 'Total_Females'})

# Sort by Total_Males in descending order (you can change this if needed)
result_sorted = result.sort_values('Total_Males', ascending=False)

# Save the results to an Excel file
excel_filename = 'ethnicity_race_sex_counts.xlsx'
result_sorted.to_excel(excel_filename)

# Display the results
print(result_sorted)
print("\n", "\n")
print(f"Results have been saved to {excel_filename}")
# Out:
# applicant_sex_name                                  Total_Females  Total_Males
# ethnicity_race_sex
# not hispanic or latino_white_male                               0        66819
# not hispanic or latino_asian_male                               0         9289
# not hispanic or latino_black or african america...              0         6588
# hispanic or latino_white_male                                   0         6199
# not hispanic or latino_american indian or alask...              0          441
# hispanic or latino_black or african american_male               0          339
# not hispanic or latino_native hawaiian or other...              0          244
# hispanic or latino_american indian or alaska na...              0          159
# hispanic or latino_native hawaiian or other pac...              0          101
# hispanic or latino_asian_male                                   0           71
# not hispanic or latino_white_female                         42594            0
# not hispanic or latino_native hawaiian or other...            161            0
# not hispanic or latino_black or african america...           7852            0
# hispanic or latino_american indian or alaska na...             80            0
# not hispanic or latino_asian_female                          6354            0
# hispanic or latino_white_female                              3476            0
# hispanic or latino_native hawaiian or other pac...             59            0
# hispanic or latino_black or african american_fe...            383            0
# hispanic or latino_asian_female                                55            0
# not hispanic or latino_american indian or alask...            351            0
#
#
#
# Results have been saved to ethnicity_race_sex_counts.xlsx

# %%
# Group by 'ethnicity_race_sex' and 'applicant_sex_name', then count
result = df.groupby(['ethnicity_race_sex', 'applicant_sex_name']).size().unstack(fill_value=0)

# Rename columns for clarity
result = result.rename(columns={'Male': 'Total_Males', 'Female': 'Total_Females'})

# Sort by the index (ethnicity_race_sex) alphabetically
result_sorted = result.sort_index()

# Save the results to an Excel file
excel_filename = 'ethnicity_race_sex_counts_ordered.xlsx'
result_sorted.to_excel(excel_filename)

print(f"Results have been saved to {excel_filename}")
# Out:
# Results have been saved to ethnicity_race_sex_counts_ordered.xlsx

# %%
print(df.columns)
# Out:
# Index(['loan_type_name', 'property_type_name', 'loan_purpose_name',
#        'loan_amount_000s', 'action_taken', 'msamd_name',
#        'applicant_ethnicity_name', 'applicant_race_name_1',
#        'applicant_sex_name', 'applicant_income_000s', 'denial_reason_name_1',
#        'denial_reason_name_2', 'denial_reason_name_3', 'rate_spread',
#        'lien_status_name', 'minority_population', 'hud_median_family_income',
#        'tract_to_msamd_income', 'ethnicity_race_sex',
#        'minority_population_missing'],
#       dtype='object')

# %% [markdown]
#    Original dataset: https://www.consumerfinance.gov/data-research/hmda/historic-data/?geo=ny&records=all-records&field_descriptions=labels
#
# # So far from original dataset:
# 1) Selected "no co-applicant" records from the column "co_applicant_ethnicity_name"
# 2) Filter columns:
#     - action_taken_name
#     - denial_reason_name_1
# 3) Created the column "action_taken":
#     - df['action_taken'] = df['action_taken_name'].replace({
#     'Loan originated': 'approved',
#     'Application approved but not accepted': 'approved',
#     'Application denied by financial institution': 'denied'
# })
# 4) First feature selection:
#     - df = df[
#
#         ['loan_type_name',
#         'property_type_name',
#         'loan_purpose_name',
#         'loan_amount_000s',
#         'action_taken',
#         'msamd_name',
#         'applicant_ethnicity_name',
#         'applicant_race_name_1',
#         'applicant_sex_name',
#         'applicant_income_000s',
#         'denial_reason_name_1',
#         'denial_reason_name_2',
#         'denial_reason_name_3',
#         'rate_spread',
#         'lien_status_name',
#         'minority_population',
#         'hud_median_family_income',
#         'tract_to_msamd_income']
#
#         ]
# 5) Excluded "Credit application incomplete" records from the column "denial_reason_name_1"
# 6) New column "ethnicity_race_sex"
